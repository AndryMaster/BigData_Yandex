# %%
from sklearn import metrics, cluster
from IPython.display import display
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
import pandas as pd
import numpy as np


def process(df: pd.DataFrame):
    x = np.arange(0, 100, dtype=np.int64)
    # y = 6 + x * 1.05 + np.random.normal(0, 10, len(x))
    # y = 8 + x * 1.03 + 17 * np.sin(2 * np.pi * x / 8)
    y = 7 + x * 1.02 + 18 * np.sin(2 * np.pi * x / 8)
    return pd.DataFrame({'x': x, 'pred': y})  #.iloc[74:]

# %%
df = pd.read_csv('ts_prediction.csv').dropna()
# df.reset_index(drop=True, inplace=True)

df.info()
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       75 non-null     int64
#  1   y       75 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB
#                x          y
# count  75.000000  75.000000
# mean   37.000000  44.764512
# std    21.794495  25.680630
# min     0.000000  -7.015464
# 25%    18.500000  24.270331
# 50%    37.000000  43.786680
# 75%    55.500000  64.791437
# max    74.000000  98.643967

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('time')
plt.ylabel('value')

x = np.arange(0, 100, dtype=np.int64)
# y = 6 + x * 1.05 + np.random.normal(0, 10, len(x))
# y = 8 + x * 1.03 + 17 * np.sin(2 * np.pi * x / 8)
y = 7 + x * 1.02 + 18 * np.sin(2 * np.pi * x / 8) + 5 * np.random.normal(0, 1, len(x))

new_df = pd.DataFrame({'x': x, 'pred': y})
display(new_df.info())

plt.plot(df.x, df.y, label='y')
plt.plot(new_df.x, new_df.pred, label='y_pred')

plt.legend()
plt.grid()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       100 non-null    int64
#  1   pred    100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB
# None
